# %%
import pandas as pd

# %%
df = pd.read_csv('../results/result.csv')
df = df[df.run >= 3].copy()
df['speed'] = df['sim-cycles'] / df['time']
df['ipc'] = df['instructions'] / df['cycles']
# df['mpki'] = df['cache-misses'] / df['instructions'] * 1000
df
# Out:
#            simulator   benchmark  sim-cycles  run    time  \
# 3    circt-verilator  RocketCore       10000    3   11003
# 4    circt-verilator  RocketCore       10000    4   11043
# 5    circt-verilator  RocketCore       10000    5   10972
# 6    circt-verilator  RocketCore       10000    6   10980
# 7    circt-verilator  RocketCore       10000    7   11099
# ..               ...         ...         ...  ...     ...
# 515           essent        FMUL       10000    5  491323
# 516           essent        FMUL       10000    6  490140
# 517           essent        FMUL       10000    7  490678
# 518           essent        FMUL       10000    8  490164
# 519           essent        FMUL       10000    9  489392
#
#      all_data_cache_accesses  cache-misses        cycles  instructions  \
# 3                108738824.0       28841.0  1.052619e+08  2.437794e+08
# 4                108528676.0       29173.0  1.063379e+08  2.437794e+08
# 5                108600112.0       29715.0  1.043215e+08  2.437794e+08
# 6                108630875.0       29249.0  1.047896e+08  2.437794e+08
# 7                108599562.0       30375.0  1.058659e+08  2.437794e+08
# ..                       ...           ...           ...           ...
# 515              787978429.0    44538991.0  2.274305e+09  1.571043e+09
# 516              788213376.0    41761961.0  2.265852e+09  1.571043e+09
# 517              787760053.0    43421183.0  2.270049e+09  1.571043e+09
# 518              787939033.0    44436880.0  2.265224e+09  1.571043e+09
# 519              788022756.0    45517364.0  2.268887e+09  1.571043e+09
#
#         speed       ipc
# 3    0.908843  2.315932
# 4    0.905551  2.292498
# 5    0.911411  2.336810
# 6    0.910747  2.326370
# 7    0.900982  2.302718
# ..        ...       ...
# 515  0.020353  0.690779
# 516  0.020402  0.693356
# 517  0.020380  0.692074
# 518  0.020401  0.693549
# 519  0.020434  0.692429
#
# [364 rows x 11 columns]

# %%
piv_abs = df.pivot_table(values='speed', columns='simulator', index='benchmark', aggfunc='mean')
piv_abs
# Out:
# simulator   circt-verilator    essent       ksim  repcut-2  verilator
# benchmark
# Conv2D             0.533193  0.078045   0.916437  0.800102   0.563399
# FMUL               0.185796  0.020383   0.465034       NaN   0.191022
# FPU                1.033532  0.937805   2.317361  1.099207   1.512349
# GEMM               0.695404  0.182191   1.608161  1.063649   0.555301
# Gemmini            0.036487  0.016409   0.166349  0.012948   0.053080
# RISCVMini          2.273988  0.954134   4.164552  2.422779   2.448834
# RocketCore         0.905997  0.174734   1.386973  0.213976   0.907353
# SHA256            14.999805  7.793450  32.802901  4.601892  13.816115
# SIGMA              0.302727  0.153629   0.574916  0.043686   0.336890
# SodorCore          4.525454  0.521497   7.799865  0.663215   4.206584
# StreamComp         0.071346       NaN   0.100806       NaN   0.019815

# %%
baseline_name = 'circt-verilator'
baseline = piv_abs[baseline_name].copy()
piv = piv_abs.apply(lambda x: x / baseline)
piv
# Out:
# simulator   circt-verilator    essent      ksim  repcut-2  verilator
# benchmark
# Conv2D                  1.0  0.146373  1.718770  1.500585   1.056651
# FMUL                    1.0  0.109704  2.502924       NaN   1.028127
# FPU                     1.0  0.907379  2.242177  1.063544   1.463282
# GEMM                    1.0  0.261993  2.312557  1.529541   0.798530
# Gemmini                 1.0  0.449720  4.559187  0.354875   1.454766
# RISCVMini               1.0  0.419586  1.831387  1.065432   1.076890
# RocketCore              1.0  0.192864  1.530879  0.236177   1.001496
# SHA256                  1.0  0.519570  2.186888  0.306797   0.921086
# SIGMA                   1.0  0.507484  1.899123  0.144308   1.112851
# SodorCore               1.0  0.115236  1.723554  0.146552   0.929538
# StreamComp              1.0       NaN  1.412916       NaN   0.277731

# %%
piv.mean()
# Out:
# simulator
# circt-verilator    1.000000
# essent             0.362991
# ksim               2.174578
# repcut-2           0.705312
# verilator          1.010995
# dtype: float64
