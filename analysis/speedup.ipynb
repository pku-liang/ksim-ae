# %%
import pandas as pd

# %%
df = pd.read_csv('../results/result.csv')
df = df[df.run >= 3].copy()
df['speed'] = df['sim-cycles'] / df['time']
df['ipc'] = df['instructions'] / df['cycles']
df['mpki'] = df['cache-misses'] / df['instructions'] * 1000
df
# Out:
#            simulator   benchmark  sim-cycles  run     time  \
# 3    circt-verilator  RocketCore      100000    3    71265
# 4    circt-verilator  RocketCore      100000    4    70857
# 5    circt-verilator  RocketCore      100000    5    70901
# 6    circt-verilator  RocketCore      100000    6    70864
# 7    circt-verilator  RocketCore      100000    7    70927
# ..               ...         ...         ...  ...      ...
# 515           essent        FMUL      100000    5  4891212
# 516           essent        FMUL      100000    6  4879775
# 517           essent        FMUL      100000    7  4887152
# 518           essent        FMUL      100000    8  4888412
# 519           essent        FMUL      100000    9  4924470
#
#      all_data_cache_accesses  cache-misses        cycles  instructions  \
# 3               8.947995e+08       30270.0  6.530126e+08  2.165281e+09
# 4               8.948287e+08       29521.0  6.529495e+08  2.165281e+09
# 5               8.947973e+08       28202.0  6.529617e+08  2.165281e+09
# 6               8.944991e+08       29138.0  6.524929e+08  2.165281e+09
# 7               8.947090e+08       32334.0  6.525907e+08  2.165281e+09
# ..                       ...           ...           ...           ...
# 515             7.858573e+09   501555136.0  2.267833e+10  1.567728e+10
# 516             7.858294e+09   509470325.0  2.263646e+10  1.567728e+10
# 517             7.857903e+09   513736498.0  2.267701e+10  1.567728e+10
# 518             7.864750e+09   500467731.0  2.268079e+10  1.567728e+10
# 519             7.889414e+09   510071164.0  2.278434e+10  1.567728e+10
#
#         speed       ipc       mpki
# 3    1.403213  3.315833   0.013980
# 4    1.411293  3.316154   0.013634
# 5    1.410417  3.316091   0.013025
# 6    1.411154  3.318474   0.013457
# 7    1.409900  3.317977   0.014933
# ..        ...       ...        ...
# 515  0.020445  0.691289  31.992483
# 516  0.020493  0.692568  32.497367
# 517  0.020462  0.691329  32.769492
# 518  0.020457  0.691214  31.923121
# 519  0.020307  0.688073  32.535691
#
# [364 rows x 12 columns]

# %%
piv_abs = df.pivot_table(values='speed', columns='simulator', index='benchmark', aggfunc='mean')
piv_abs
# Out:
# simulator   circt-verilator     essent       ksim  repcut-2  verilator
# benchmark
# Conv2D             0.695280   0.079723   0.926780  0.842679   0.640289
# FMUL               0.226831   0.020308   0.472457       NaN   0.226935
# FPU                1.292098   1.037111   2.752046  1.207893   1.981222
# GEMM               0.966793   0.183715   1.603973  1.105652   0.869056
# GemminiFP          0.020056   0.016410   0.167551  0.013176   0.024993
# RISCVMini          3.976173   0.963490   4.126928  2.468771   4.098835
# RocketCore         1.410177   0.179804   1.375372  0.216388   1.761232
# SHA256            19.501202  10.216403  32.537384  4.842512  18.362860
# SIGMAFP            0.334408   0.149624   0.613123  0.042230   0.399520
# SodorCore          6.541203   0.541038   7.860305  0.675681   6.190005
# StreamComp         0.106362        NaN   0.100404       NaN   0.026255

# %%
baseline_name = 'circt-verilator'
baseline = piv_abs[baseline_name].copy()
piv = piv_abs.apply(lambda x: x / baseline)
piv
# Out:
# simulator   circt-verilator    essent      ksim  repcut-2  verilator
# benchmark
# Conv2D                  1.0  0.114663  1.332961  1.212000   0.920909
# FMUL                    1.0  0.089528  2.082861       NaN   1.000459
# FPU                     1.0  0.802657  2.129905  0.934831   1.533337
# GEMM                    1.0  0.190025  1.659066  1.143628   0.898906
# GemminiFP               1.0  0.818205  8.354131  0.656960   1.246145
# RISCVMini               1.0  0.242316  1.037915  0.620891   1.030849
# RocketCore              1.0  0.127504  0.975319  0.153447   1.248944
# SHA256                  1.0  0.523886  1.668481  0.248319   0.941627
# SIGMAFP                 1.0  0.447431  1.833460  0.126283   1.194710
# SodorCore               1.0  0.082712  1.201661  0.103296   0.946310
# StreamComp              1.0       NaN  0.943984       NaN   0.246843
